# %%
# prompt: input data spreasheet berikut, sheet Tebu
# https://docs.google.com/spreadsheets/d/1D0zrzSnWF0il_TXiGxXzkDT_-ubFHCNT_SjBEpCKX-k/edit?gid=724721831#gid=724721831

import pandas as pd

sheet_url = 'https://docs.google.com/spreadsheets/d/1D0zrzSnWF0il_TXiGxXzkDT_-ubFHCNT_SjBEpCKX-k/edit?gid=724721831#gid=724721831'
try:
  sheet_id = sheet_url.split('/')[5]
  sheet_name = 'Tebu' # Specify the sheet name
  url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'
  df_tebu = pd.read_csv(url)
  print(df_tebu)
except Exception as e:
  print(f"Error: {e}")
# Out:
#      Tebu Area (Kecamatan)  Koordinat X  Koordinat Y      Location  \
# 0    Tebu      Bangsalsari  113.5890168    -8.185728    Location_1
# 1    Tebu       Tempurejo   113.7398625    -8.367988    Location_2
# 2    Tebu       Sumberbaru  113.4271599    -8.086981    Location_3
# 3    Tebu           Mayang  113.7848458    -8.174721    Location_4
# 4    Tebu      Mumbulsari   113.7331134    -8.272063    Location_5
# ..    ...              ...          ...          ...           ...
# 136  Tebu         Glenmore  114.0499567    -8.338308  Location_137
# 137  Tebu         Glenmore  114.0483200    -8.352445  Location_138
# 138  Tebu         Glenmore  114.0499604    -8.359667  Location_139
# 139  Tebu        Kalipuro     114.36509    -8.159674  Location_140
# 140  Tebu       Wongsorejo   114.417266    -8.057668  Location_141
#
#     Tanggal Pengambilan Data Class
# 0                 20/10/2024  Tebu
# 1                 13/10/2024  Tebu
# 2                 13/10/2024  Tebu
# ...

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1D0zrzSnWF0il_TXiGxXzkDT_-ubFHCNT_SjBEpCKX-k/edit?gid=724721831#gid=724721831'
try:
  sheet_id = sheet_url.split('/')[5]
  sheet_name = 'Jagung' # Specify the sheet name
  url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'
  df_jagung = pd.read_csv(url)
  print(df_jagung)
except Exception as e:
  print(f"Error: {e}")
# Out:
#     Komoditas Area (Kecamatan)  Koordinat X Koordinat Y      Location  \
# 0      Jagung            Panti  113.647.129  -8.124.436    Location_1
# 1      Jagung          Patrang  113.6823043  -8.1386776    Location_2
# 2      Jagung          Patrang   113.711611   -8.115392    Location_3
# 3      Jagung     Sumberjambe   113.8754438  -8.0681813    Location_4
# 4      Jagung           Ambulu  113.6385132  -8.3745527    Location_5
# ..        ...              ...          ...         ...           ...
# 311    Jagung           Glagah  114.3346491  -8.2199256  Location_312
# 312    Jagung             Giri  114.3419185  -8.2005139  Location_313
# 313    Jagung      Tegaldlimo   114.3105799  -8.5374417  Location_314
# 314    Jagung        Rogojampi   114.300711   -8.340429  Location_315
# 315    Jagung           Glagah    114.33356   -8.220116  Location_316
#
#     Tanggal Pengambilan Data   Class
# 0                 12/10/2024  Jagung
# 1                 12/10/2024  Jagung
# ...

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1D0zrzSnWF0il_TXiGxXzkDT_-ubFHCNT_SjBEpCKX-k/edit?gid=724721831#gid=724721831'
try:
  sheet_id = sheet_url.split('/')[5]
  sheet_name = 'Padi' # Specify the sheet name
  url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'
  df_padi = pd.read_csv(url)
  print(df_padi)
except Exception as e:
  print(f"Error: {e}")
# Out:
#     Komoditas Area (Kecamatan)  Koordinat X  Koordinat Y      Location  \
# 0        Padi        Jenggawah  113.6572062    -8.313155    Location_1
# 1        Padi          Patrang  113.6747281    -8.126345    Location_2
# 2        Padi        Rambipuji  113.6137447    -8.197671    Location_3
# 3        Padi        Rambipuji  113.6176363    -8.216875    Location_4
# 4        Padi           Mayang   113.828751    -8.182679    Location_5
# ..        ...              ...          ...          ...           ...
# 355      Padi       Siliragung  114.1155982    -8.526762  Location_356
# 356      Padi       Siliragung  114.1125919    -8.545490  Location_357
# 357      Padi       Siliragung  114.1140169    -8.572966  Location_358
# 358      Padi       Purwoharjo    114.27097    -8.496635  Location_359
# 359      Padi       Tegaldlimo   114.321122    -8.507795  Location_360
#
#     Tanggal Pengambilan Data Class
# 0                 13/10/2024  Padi
# 1                 12/10/2024  Padi
# ...

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1D0zrzSnWF0il_TXiGxXzkDT_-ubFHCNT_SjBEpCKX-k/edit?gid=724721831#gid=724721831'
try:
  sheet_id = sheet_url.split('/')[5]
  sheet_name = 'Others' # Specify the sheet name
  url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'
  df_others = pd.read_csv(url)
  print(df_others)
except Exception as e:
  print(f"Error: {e}")
# Out:
#                Komoditas Area (Kecamatan)  Koordinat X Koordinat Y  \
# 0              Ubi jalar            Panti  113.6042792  -8.1346699
# 1              Ubi jalar        Rogojampi   114.291161   -8.342823
# 2              Ubi jalar        Rogojampi   114.281895   -8.338908
# 3              Ubi jalar          Songgon   114.238234   -8.267071
# 4              Ubi jalar            Kabat   114.289385   -8.271245
# ..                   ...              ...          ...         ...
# 536         Bawang Merah          Cluring  114.2002322  -8.4386848
# 537         Bawang Merah          Cluring  114.1970159  -8.4409174
# 538         Bawang merah          Genteng  114.1774207  -8.3752469
# 539  Agroforestri kelapa         Glenmore  114.0418220  -8.2571320
# 540  Agroforestri kelapa         Glenmore  114.0418220  -8.2571320
#
#          Location Tanggal Pengambilan Data   Class
# 0      Location_1               13/10/2024  Others
# 1      Location_2               06/10/2024  Others
# ...

# %%
## Others

# ... (Your existing code to load df_others) ...

# Assuming df_others has columns 'Koordinat X', 'Koordinat Y', and 'Location'
locations_data = []
for index, row in df_others.iterrows():
    location_data = {
      'name': row['Location'],
      'geometry': f"ee.Geometry.Point([{row['Koordinat X']}, {row['Koordinat Y']}])"
    }
    locations_data.append(location_data)

# Convert to Javascript array format
js_output = "var locations = [\n"
for item in locations_data:
    js_output += f"  {{name: '{item['name']}', geometry: {item['geometry']}}},\n"
js_output = js_output[:-2] + "\n];"  # Remove the last comma and add closing bracket

js_output
# Out:
# "var locations = [\n  {name: 'Location_1', geometry: ee.Geometry.Point([113.6042792, -8.1346699])},\n  {name: 'Location_2', geometry: ee.Geometry.Point([114.291161, -8.342823])},\n  {name: 'Location_3', geometry: ee.Geometry.Point([114.281895, -8.338908])},\n  {name: 'Location_4', geometry: ee.Geometry.Point([114.238234, -8.267071])},\n  {name: 'Location_5', geometry: ee.Geometry.Point([114.289385, -8.271245])},\n  {name: 'Location_6', geometry: ee.Geometry.Point([114.291161, -8.342823])},\n  {name: 'Location_7', geometry: ee.Geometry.Point([114.281895, -8.338908])},\n  {name: 'Location_8', geometry: ee.Geometry.Point([114.238234, -8.267071])},\n  {name: 'Location_9', geometry: ee.Geometry.Point([114.289385, -8.271245])},\n  {name: 'Location_10', geometry: ee.Geometry.Point([113.5869116, -8. 1539241])},\n  {name: 'Location_11', geometry: ee.Geometry.Point([114.2460000, -8.2745980])},\n  {name: 'Location_12', geometry: ee.Geometry.Point([114.2460000, -8.2745980])},\n  {name: 'Location
# ...

# %%
## Padi

# ... (Your existing code to load df_others) ...

# Assuming df_others has columns 'Koordinat X', 'Koordinat Y', and 'Location'
locations_data = []
for index, row in df_padi.iterrows():
    location_data = {
      'name': row['Location'],
      'geometry': f"ee.Geometry.Point([{row['Koordinat X']}, {row['Koordinat Y']}])"
    }
    locations_data.append(location_data)

# Convert to Javascript array format
js_output = "var locations = [\n"
for item in locations_data:
    js_output += f"  {{name: '{item['name']}', geometry: {item['geometry']}}},\n"
js_output = js_output[:-2] + "\n];"  # Remove the last comma and add closing bracket

js_output
# Out:
# "var locations = [\n  {name: 'Location_1', geometry: ee.Geometry.Point([113.6572062, -8.3131553])},\n  {name: 'Location_2', geometry: ee.Geometry.Point([113.6747281, -8.126345])},\n  {name: 'Location_3', geometry: ee.Geometry.Point([113.6137447, -8.197671])},\n  {name: 'Location_4', geometry: ee.Geometry.Point([113.6176363, -8.216875])},\n  {name: 'Location_5', geometry: ee.Geometry.Point([113.828751, -8.182679])},\n  {name: 'Location_6', geometry: ee.Geometry.Point([113.5896353, -8.2080691])},\n  {name: 'Location_7', geometry: ee.Geometry.Point([113.8081422, -8.1778607])},\n  {name: 'Location_8', geometry: ee.Geometry.Point([113.3701317, -8.2255255])},\n  {name: 'Location_9', geometry: ee.Geometry.Point([113.7229582, -8.2671464])},\n  {name: 'Location_10', geometry: ee.Geometry.Point([113.6739124, -8.187615])},\n  {name: 'Location_11', geometry: ee.Geometry.Point([113.7965366, -8.1759591])},\n  {name: 'Location_12', geometry: ee.Geometry.Point([113.7441651, -8.2770931])},\n  {name: 
# ...

# %%
## Jagung

# ... (Your existing code to load df_others) ...

# Assuming df_others has columns 'Koordinat X', 'Koordinat Y', and 'Location'
locations_data = []
for index, row in df_jagung.iterrows():
    location_data = {
      'name': row['Location'],
      'geometry': f"ee.Geometry.Point([{row['Koordinat X']}, {row['Koordinat Y']}])"
    }
    locations_data.append(location_data)

# Convert to Javascript array format
js_output = "var locations = [\n"
for item in locations_data:
    js_output += f"  {{name: '{item['name']}', geometry: {item['geometry']}}},\n"
js_output = js_output[:-2] + "\n];"  # Remove the last comma and add closing bracket

js_output
# Out:
# "var locations = [\n  {name: 'Location_1', geometry: ee.Geometry.Point([113.647.129, -8.124.436])},\n  {name: 'Location_2', geometry: ee.Geometry.Point([113.6823043, -8.1386776])},\n  {name: 'Location_3', geometry: ee.Geometry.Point([113.711611, -8.115392])},\n  {name: 'Location_4', geometry: ee.Geometry.Point([113.8754438, -8.0681813])},\n  {name: 'Location_5', geometry: ee.Geometry.Point([113.6385132, -8.3745527])},\n  {name: 'Location_6', geometry: ee.Geometry.Point([113. 6824807, -8.1463733])},\n  {name: 'Location_7', geometry: ee.Geometry.Point([113.743197, -8.154156])},\n  {name: 'Location_8', geometry: ee.Geometry.Point([113.4803414, -8.1631425])},\n  {name: 'Location_9', geometry: ee.Geometry.Point([113.6629170, -8.1634246])},\n  {name: 'Location_10', geometry: ee.Geometry.Point([113.6466796, -8.2975855])},\n  {name: 'Location_11', geometry: ee.Geometry.Point([113.6516088, -8.3771715])},\n  {name: 'Location_12', geometry: ee.Geometry.Point([113.9100849, -8.0325328])},\n  {nam
# ...
